# %% [markdown]
# # Comic Genre Classifier by Zach & Brooke

# %% [markdown]
# ## Scraping Webtoons for URLs of Comic Episodes

# %%
import os
import pandas as pd
import httpx
import aiohttp
import asyncio
import aiofiles
from bs4 import BeautifulSoup
import requests
import re
import nest_asyncio
import time
import random

nest_asyncio.apply()

semaphore = asyncio.Semaphore(100)

pd.set_option('display.width', 100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
#       2 import pandas as pd
# ----> 3 import httpx
#       4 import asyncio
#       5 import aiofiles
#
# ModuleNotFoundError: No module named 'httpx'

# %%
import asyncio
import aiohttp
import time

def create_series_url_with_genres_dict():
    """
    Creates a dictionary associating each WebToons original comic series URL to its associated genre.

    Returns:
        series_url_genre_dict (Dict(string,string)): A Dictionary mapping comic series URLs to their associated genres
    """
    series_url_genre_dict = {}
    start = time.time()

    originals_url = "https://www.webtoons.com/en/originals" # URL for WebToons original comic series
    r = requests.get(originals_url)
    soup = BeautifulSoup(r.text, 'html.parser')

    completed_comics = soup.find('div', class_='daily_section on').find_all('a', href=True) # Get HTML objects of all completed series

    for comic_series in completed_comics:
        series_url = comic_series['href']
        genre = comic_series.find('p', class_=re.compile("^genre.*")).text
        series_url_genre_dict[series_url] = genre # Add URL : associated genre for all completed series
    
    ongoing_comics_days = soup.find_all('div', class_=re.compile('daily_section\s+_list_\w*')) # Get HTML objects of lists of ongoing series released on each day of the week
    
    for ongoing_comics_day in ongoing_comics_days:
        daily_ongoing_comics = ongoing_comics_day.find_all('li') # Get HTML objects of all ongoing series for each day of the week
        for comic_series in daily_ongoing_comics:
            series_url = comic_series.find('a', href=True)['href']
            genre = comic_series.find('p', class_=re.compile("^genre.*")).text
            series_url_genre_dict[series_url] = genre # Add URL : associated genre for all ongoing series
    
    print(f"Finished asyncio episode url dict in {time.time()- start}s")
    return series_url_genre_dict

async def fetch_episode_url_genre_dict(session, comic_series_url, genre):
    """
    Helper function for create_episode_url_with_genres_dict. 
    Fetches the episode_url_genre_dict for a given series

    Args:
        session (aiohttp.client.ClientSession()): Allows asynchronous processing of requests
        comic_series_url (string): WebToon original comic series URL 
        genre (string): Genre associated with the comic
    Returns:
        episode_url_genre_dict(Dict(string,string)): A Dictionary mapping comic episode URLs from one series to their associated genres
    """
    async with session.get(comic_series_url) as response: # Request response
        episode_url_genre_dict = {}
        
        r = await response.text() # Await a response
        soup = BeautifulSoup(r, 'html.parser') # Use BeautifulSoup on response

        comic_episodes = soup.find_all('li', class_='_episodeItem') # Get HTML objects of all episodes of each series
        for episode in comic_episodes:
            episode_url = episode.find('a', href=True)['href']
            episode_url_genre_dict[episode_url] = genre # Add URL : associated genre for all episodes
        
        return episode_url_genre_dict

async def create_episode_url_with_genres_dict(series_url_genre_dict): # Scrape episode URLs for each comic series URL
    """
    Creates a dictionary associating each WebToons original comic episode URL to its associated genre.

    Args:
        series_url_genre_dict (Dict(string,string)): A Dictionary mapping comic series URLs to their associated genres
    Returns:
        episode_url_genre_dict (Dict(string,string)): A Dictionary mapping comic episode URLs to their associated genres
    """
    tasks = []
    start = time.time()
    async with aiohttp.ClientSession() as session: # Allows asynchronous processing of requests
        async with asyncio.TaskGroup() as tg: # Gathers all tasks (if any error, the whole thing errors)
            for comic_series_url, genre in series_url_genre_dict.items():
                task = tg.create_task(fetch_episode_url_genre_dict(session, comic_series_url, genre)) # Create task for fetching 
                tasks.append(task)
    print(f"Finished asyncio episode url dict in {time.time()- start}s")
    episode_url_genre_dict = {comic_episode_url: genre for task in tasks for comic_episode_url, genre in task.result().items()} # Extract and concatenate dictionaries inside finished tasks
    return episode_url_genre_dict

series_url_genre_dict = create_series_url_with_genres_dict()
episode_url_genre_dict = await create_episode_url_with_genres_dict(series_url_genre_dict)
# Out:
# Finished asyncio episode url dict in 0.9420039653778076s
# Finished asyncio episode url dict in 9.304094076156616s

# %%
episode_url_genre_dict
# Out:
# {'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-7-coffee-for-one/viewer?title_no=6596&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-6-late/viewer?title_no=6596&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-5-portraits/viewer?title_no=6596&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-4-how-to-drive/viewer?title_no=6596&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-3-the-golden-hour/viewer?title_no=6596&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-2-magic-specialists/viewer?title_no=6596&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-mushroom-girl/ep-1-wake-up/viewer?title_no=6596&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-14/viewer?title_no=1285&episode_no=15': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-13/viewer?title_no=1285&episode_no=14': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-12/viewer?title_no=1285&episode_no=13': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-11/viewer?title_no=1285&episode_no=12': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-10/viewer?title_no=1285&episode_no=11': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-9/viewer?title_no=1285&episode_no=10': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-8/viewer?title_no=1285&episode_no=9': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-7/viewer?title_no=1285&episode_no=8': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-6/viewer?title_no=1285&episode_no=7': 'Thriller',
#  'https://www.webtoons.com/en/thriller/sweethome/ep-5/viewer?title_no=1285&episode_no=6': 'Thriller',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-6/viewer?title_no=3908&episode_no=6': 'Drama',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-5/viewer?title_no=3908&episode_no=5': 'Drama',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-4/viewer?title_no=3908&episode_no=4': 'Drama',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-3/viewer?title_no=3908&episode_no=3': 'Drama',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-2/viewer?title_no=3908&episode_no=2': 'Drama',
#  'https://www.webtoons.com/en/drama/daytime-star/episode-1/viewer?title_no=3908&episode_no=1': 'Drama',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-7/viewer?title_no=4572&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-6/viewer?title_no=4572&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-5/viewer?title_no=4572&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-4/viewer?title_no=4572&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-3/viewer?title_no=4572&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-2/viewer?title_no=4572&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/marry-my-husband/episode-1/viewer?title_no=4572&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-14/viewer?title_no=6722&episode_no=14': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-13/viewer?title_no=6722&episode_no=13': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-12/viewer?title_no=6722&episode_no=12': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-11/viewer?title_no=6722&episode_no=11': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-10/viewer?title_no=6722&episode_no=10': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-9/viewer?title_no=6722&episode_no=9': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-8/viewer?title_no=6722&episode_no=8': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-7/viewer?title_no=6722&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-6/viewer?title_no=6722&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/glacias/jukas-tale-ep-5/viewer?title_no=6722&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/6-the-wolves-who-jumped-over-the-fence/viewer?title_no=3785&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/5-clean-the-room-and-reveal-the-big-secret/viewer?title_no=3785&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/4-one-step-back-two-steps-forward/viewer?title_no=3785&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/3-its-nice-to-meet-you/viewer?title_no=3785&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/2-hello-heli/viewer?title_no=3785&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/dark-moon-the-blood-altar/1-the-first-encounter/viewer?title_no=3785&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-7/viewer?title_no=3065&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-6/viewer?title_no=3065&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-5/viewer?title_no=3065&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-4/viewer?title_no=3065&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-3/viewer?title_no=3065&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-2/viewer?title_no=3065&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/there-must-be-happy-endings/episode-1/viewer?title_no=3065&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-cursed-charm/episode-3/viewer?title_no=4678&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-cursed-charm/episode-2/viewer?title_no=4678&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-cursed-charm/episode-1/viewer?title_no=4678&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-7/viewer?title_no=3039&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-6/viewer?title_no=3039&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-5/viewer?title_no=3039&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-4/viewer?title_no=3039&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-3/viewer?title_no=3039&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-2/viewer?title_no=3039&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-wicked-heroines-stepmother/episode-1/viewer?title_no=3039&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-6/viewer?title_no=2534&episode_no=7': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-5/viewer?title_no=2534&episode_no=6': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-4/viewer?title_no=2534&episode_no=5': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-3/viewer?title_no=2534&episode_no=4': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-2/viewer?title_no=2534&episode_no=3': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-1/viewer?title_no=2534&episode_no=2': 'Thriller',
#  'https://www.webtoons.com/en/thriller/shotgun-boy/ep-0-prologue/viewer?title_no=2534&episode_no=1': 'Thriller',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-9-return/viewer?title_no=6594&episode_no=9': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-8-base-case/viewer?title_no=6594&episode_no=8': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-7-break/viewer?title_no=6594&episode_no=7': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-6-null/viewer?title_no=6594&episode_no=6': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-5-scheduling/viewer?title_no=6594&episode_no=5': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-4-virtual/viewer?title_no=6594&episode_no=4': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-3-interface/viewer?title_no=6594&episode_no=3': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-2-parameters/viewer?title_no=6594&episode_no=2': 'Sci-fi',
#  'https://www.webtoons.com/en/sf/miracle-simulator/ep-1-query/viewer?title_no=6594&episode_no=1': 'Sci-fi',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-7/viewer?title_no=3689&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-6/viewer?title_no=3689&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-5/viewer?title_no=3689&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-4/viewer?title_no=3689&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-3/viewer?title_no=3689&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-2/viewer?title_no=3689&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/bitten-contract/episode-1/viewer?title_no=3689&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-9/viewer?title_no=2606&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-8/viewer?title_no=2606&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-7/viewer?title_no=2606&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-6/viewer?title_no=2606&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-5/viewer?title_no=2606&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-4/viewer?title_no=2606&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-3/viewer?title_no=2606&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-2/viewer?title_no=2606&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/my-gently-raised-beast/episode-1/viewer?title_no=2606&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-12-intruder-part-3/viewer?title_no=6591&episode_no=13': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-11-intruder-part-2/viewer?title_no=6591&episode_no=12': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-10-intruder-part-1/viewer?title_no=6591&episode_no=11': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-9-far-fetched-part-3/viewer?title_no=6591&episode_no=10': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-8-far-fetched-part-2/viewer?title_no=6591&episode_no=9': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-7-far-fetched-part-1/viewer?title_no=6591&episode_no=8': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-6-the-leap-part-3/viewer?title_no=6591&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-5-the-leap-part-2/viewer?title_no=6591&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-4-the-leap-part-1/viewer?title_no=6591&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/icy-copper/ep-3-king-of-fools-part-3/viewer?title_no=6591&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-9/viewer?title_no=3115&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-8/viewer?title_no=3115&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-7/viewer?title_no=3115&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-6/viewer?title_no=3115&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-5/viewer?title_no=3115&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-4/viewer?title_no=3115&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-3/viewer?title_no=3115&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-2/viewer?title_no=3115&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/til-debt-do-us-part/episode-1/viewer?title_no=3115&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-return-of-elena-the-knight/episode-3/viewer?title_no=5720&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-return-of-elena-the-knight/episode-2/viewer?title_no=5720&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-return-of-elena-the-knight/episode-1/viewer?title_no=5720&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-7/viewer?title_no=1436&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-6/viewer?title_no=1436&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-5/viewer?title_no=1436&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-4/viewer?title_no=1436&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-3/viewer?title_no=1436&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-2/viewer?title_no=1436&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-1/viewer?title_no=1436&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/truebeauty/episode-0-/viewer?title_no=1436&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-7/viewer?title_no=3484&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-6/viewer?title_no=3484&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-5/viewer?title_no=3484&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-4/viewer?title_no=3484&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-3/viewer?title_no=3484&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-2/viewer?title_no=3484&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/perfect-marriage-revenge/episode-1/viewer?title_no=3484&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-7/viewer?title_no=3790&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-6/viewer?title_no=3790&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-5/viewer?title_no=3790&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-4/viewer?title_no=3790&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-3/viewer?title_no=3790&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-2/viewer?title_no=3790&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/secretary-out-of-order/episode-1/viewer?title_no=3790&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-7/viewer?title_no=2448&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-6/viewer?title_no=2448&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-5/viewer?title_no=2448&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-4/viewer?title_no=2448&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-3/viewer?title_no=2448&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-2/viewer?title_no=2448&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-newlywed-diary-of-a-witch-and-a-dragon/episode-1/viewer?title_no=2448&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-7/viewer?title_no=3691&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-6/viewer?title_no=3691&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-5/viewer?title_no=3691&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-4/viewer?title_no=3691&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-3/viewer?title_no=3691&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-2/viewer?title_no=3691&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-runway/episode-1/viewer?title_no=3691&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-7/viewer?title_no=2521&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-6/viewer?title_no=2521&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-5/viewer?title_no=2521&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-4/viewer?title_no=2521&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-3/viewer?title_no=2521&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-2/viewer?title_no=2521&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/act-like-you-love-me/episode-1/viewer?title_no=2521&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-7/viewer?title_no=2186&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-6/viewer?title_no=2186&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-5/viewer?title_no=2186&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-4/viewer?title_no=2186&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-3/viewer?title_no=2186&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-2/viewer?title_no=2186&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-makeup-remover/episode-1/viewer?title_no=2186&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-7/viewer?title_no=2674&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-6/viewer?title_no=2674&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-5/viewer?title_no=2674&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-4/viewer?title_no=2674&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-3/viewer?title_no=2674&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-2/viewer?title_no=2674&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/his-majestys-proposal/episode-1/viewer?title_no=2674&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-7-the-strong/viewer?title_no=2027&episode_no=7': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-6-the-bitter-struggle/viewer?title_no=2027&episode_no=6': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-5-courage/viewer?title_no=2027&episode_no=5': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-4-the-night-before/viewer?title_no=2027&episode_no=4': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-3-the-build-up/viewer?title_no=2027&episode_no=3': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-2-the-omen/viewer?title_no=2027&episode_no=2': 'Sports',
#  'https://www.webtoons.com/en/sports/the-boxer/ep-1-the-genius/viewer?title_no=2027&episode_no=1': 'Sports',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-7/viewer?title_no=5230&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-6/viewer?title_no=5230&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-5/viewer?title_no=5230&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-4/viewer?title_no=5230&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-3/viewer?title_no=5230&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-2/viewer?title_no=5230&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/my-far-too-tumultuous-marriage/episode-1/viewer?title_no=5230&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-7/viewer?title_no=4209&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-6/viewer?title_no=4209&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-5/viewer?title_no=4209&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-4/viewer?title_no=4209&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-3/viewer?title_no=4209&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-2/viewer?title_no=4209&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/twilight-poem/episode-1/viewer?title_no=4209&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-7/viewer?title_no=5449&episode_no=7': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-6/viewer?title_no=5449&episode_no=6': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-5/viewer?title_no=5449&episode_no=5': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-4/viewer?title_no=5449&episode_no=4': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-3/viewer?title_no=5449&episode_no=3': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-2/viewer?title_no=5449&episode_no=2': 'Drama',
#  'https://www.webtoons.com/en/drama/i-dont-hate-us/episode-1/viewer?title_no=5449&episode_no=1': 'Drama',
#  'https://www.webtoons.com/en/romance/a-heart-for-the-emperor/episode-3/viewer?title_no=4269&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/a-heart-for-the-emperor/episode-2/viewer?title_no=4269&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/a-heart-for-the-emperor/episode-1/viewer?title_no=4269&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-7/viewer?title_no=3412&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-6/viewer?title_no=3412&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-5/viewer?title_no=3412&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-4/viewer?title_no=3412&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-3/viewer?title_no=3412&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-2/viewer?title_no=3412&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-male-leads-girl-friend/episode-1/viewer?title_no=3412&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-8/viewer?title_no=4747&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-7/viewer?title_no=4747&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-6/viewer?title_no=4747&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-5/viewer?title_no=4747&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-4/viewer?title_no=4747&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-3/viewer?title_no=4747&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-2/viewer?title_no=4747&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/night-owls-and-summer-skies/episode-1/viewer?title_no=4747&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-12/viewer?title_no=2114&episode_no=12': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-11/viewer?title_no=2114&episode_no=11': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-10/viewer?title_no=2114&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-9/viewer?title_no=2114&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-8/viewer?title_no=2114&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-7/viewer?title_no=2114&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-6/viewer?title_no=2114&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-5/viewer?title_no=2114&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-4/viewer?title_no=2114&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/to-love-your-enemy/episode-3/viewer?title_no=2114&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-9/viewer?title_no=2066&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-8/viewer?title_no=2066&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-7/viewer?title_no=2066&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-6/viewer?title_no=2066&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-5/viewer?title_no=2066&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-4/viewer?title_no=2066&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-3/viewer?title_no=2066&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-2/viewer?title_no=2066&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/nice-to-meet-you/episode-1/viewer?title_no=2066&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-7/viewer?title_no=3993&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-6/viewer?title_no=3993&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-5/viewer?title_no=3993&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-4/viewer?title_no=3993&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-3/viewer?title_no=3993&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-2/viewer?title_no=3993&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/my-reason-to-die/episode-1/viewer?title_no=3993&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-7/viewer?title_no=1267&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-6/viewer?title_no=1267&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-5/viewer?title_no=1267&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-4/viewer?title_no=1267&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-3/viewer?title_no=1267&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-2/viewer?title_no=1267&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/the-first-night-with-the-duke/episode-1/viewer?title_no=1267&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/romance/antistalker/episode-7/viewer?title_no=2087&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-6/viewer?title_no=2087&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-5/viewer?title_no=2087&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-4/viewer?title_no=2087&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-3/viewer?title_no=2087&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-2/viewer?title_no=2087&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/antistalker/episode-1/viewer?title_no=2087&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-7/viewer?title_no=5798&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-6/viewer?title_no=5798&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-5/viewer?title_no=5798&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-4/viewer?title_no=5798&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-3/viewer?title_no=5798&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-2/viewer?title_no=5798&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/hashtag-muted/episode-1/viewer?title_no=5798&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-7-a-secret/viewer?title_no=5137&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-6-master/viewer?title_no=5137&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-5-aoi-san/viewer?title_no=5137&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-4-a-childhood-friend/viewer?title_no=5137&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-3-girls/viewer?title_no=5137&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-2-junior/viewer?title_no=5137&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/senpai-is-an-otokonoko/ep-1-a-letter/viewer?title_no=5137&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/action/noblesse/ep-50/viewer?title_no=87&episode_no=50': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-49/viewer?title_no=87&episode_no=49': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-48/viewer?title_no=87&episode_no=48': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-47/viewer?title_no=87&episode_no=47': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-46/viewer?title_no=87&episode_no=46': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-45/viewer?title_no=87&episode_no=45': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-44/viewer?title_no=87&episode_no=44': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-43/viewer?title_no=87&episode_no=43': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-42/viewer?title_no=87&episode_no=42': 'Action',
#  'https://www.webtoons.com/en/action/noblesse/ep-41/viewer?title_no=87&episode_no=41': 'Action',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-21/viewer?title_no=425&episode_no=21': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-20/viewer?title_no=425&episode_no=20': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-19/viewer?title_no=425&episode_no=19': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-18/viewer?title_no=425&episode_no=18': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-17/viewer?title_no=425&episode_no=17': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-16/viewer?title_no=425&episode_no=16': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-15/viewer?title_no=425&episode_no=15': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-14/viewer?title_no=425&episode_no=14': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-13/viewer?title_no=425&episode_no=13': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/hooky/ep-12/viewer?title_no=425&episode_no=12': 'Fantasy',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-8/viewer?title_no=1652&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-7/viewer?title_no=1652&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-6/viewer?title_no=1652&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-5/viewer?title_no=1652&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-4/viewer?title_no=1652&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-3/viewer?title_no=1652&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-2/viewer?title_no=1652&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/brass-and-sass/episode-1/viewer?title_no=1652&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-16-not-a-threat/viewer?title_no=1467&episode_no=16': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-15-can-you-see-me/viewer?title_no=1467&episode_no=15': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-14/viewer?title_no=1467&episode_no=14': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-13-green-glitter/viewer?title_no=1467&episode_no=13': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-12/viewer?title_no=1467&episode_no=12': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-11/viewer?title_no=1467&episode_no=11': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-10/viewer?title_no=1467&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-9/viewer?title_no=1467&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-8/viewer?title_no=1467&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/freaking-romance/episode-7/viewer?title_no=1467&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-7/viewer?title_no=2921&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-6/viewer?title_no=2921&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-5/viewer?title_no=2921&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-4/viewer?title_no=2921&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-3/viewer?title_no=2921&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-2/viewer?title_no=2921&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/sixth-sense-kiss/episode-1/viewer?title_no=2921&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-17/viewer?title_no=1577&episode_no=17': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-16/viewer?title_no=1577&episode_no=16': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-15/viewer?title_no=1577&episode_no=15': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-14/viewer?title_no=1577&episode_no=14': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-13/viewer?title_no=1577&episode_no=13': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-12/viewer?title_no=1577&episode_no=12': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-11/viewer?title_no=1577&episode_no=11': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-10/viewer?title_no=1577&episode_no=10': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-9/viewer?title_no=1577&episode_no=9': 'Drama',
#  'https://www.webtoons.com/en/drama/spirit-fingers/episode-8/viewer?title_no=1577&episode_no=8': 'Drama',
#  'https://www.webtoons.com/en/romance/the-dukes-teddy-bear/episode-4/viewer?title_no=5045&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-teddy-bear/episode-3/viewer?title_no=5045&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-teddy-bear/episode-2/viewer?title_no=5045&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-dukes-teddy-bear/episode-1/viewer?title_no=5045&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-8/viewer?title_no=1498&episode_no=8': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-7/viewer?title_no=1498&episode_no=7': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-6/viewer?title_no=1498&episode_no=6': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-5/viewer?title_no=1498&episode_no=5': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-4/viewer?title_no=1498&episode_no=4': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-3/viewer?title_no=1498&episode_no=3': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-2/viewer?title_no=1498&episode_no=2': 'Comedy',
#  'https://www.webtoons.com/en/comedy/love-advice/episode-1/viewer?title_no=1498&episode_no=1': 'Comedy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-7/viewer?title_no=2737&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-6/viewer?title_no=2737&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-5/viewer?title_no=2737&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-4/viewer?title_no=2737&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-3/viewer?title_no=2737&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-2/viewer?title_no=2737&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/happily-ever-afterwards/episode-1/viewer?title_no=2737&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/romance/taming-the-marquess/episode-3/viewer?title_no=4345&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/taming-the-marquess/episode-2/viewer?title_no=4345&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/taming-the-marquess/episode-1/viewer?title_no=4345&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/action/viral-hit/ep-10-how-to-win-a-fight-against-an-amateur/viewer?title_no=2268&episode_no=10': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-9-i-want-to-rip-myself-to-shreds/viewer?title_no=2268&episode_no=9': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-8-im-gonna-ask-you-out-bomi-choi/viewer?title_no=2268&episode_no=8': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-7-wake-up-you-fking-creep/viewer?title_no=2268&episode_no=7': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-6-we-made-17000/viewer?title_no=2268&episode_no=6': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-5-how-to-get-hit-so-it-doesnt-hurt/viewer?title_no=2268&episode_no=5': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-4-lesson-one-dont-lose-your-cool/viewer?title_no=2268&episode_no=4': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-3-you-can-learn-how-to-fight-from-newtube/viewer?title_no=2268&episode_no=3': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-2-calling-out-bullies-on-camera/viewer?title_no=2268&episode_no=2': 'Action',
#  'https://www.webtoons.com/en/action/viral-hit/ep-1-everyone-and-their-mother-thinks-theyre-a-newtuber/viewer?title_no=2268&episode_no=1': 'Action',
#  'https://www.webtoons.com/en/romance/skylie/ep-9-realization/viewer?title_no=5881&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-8-something-wrong/viewer?title_no=5881&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-7-rejected/viewer?title_no=5881&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-6-a-date/viewer?title_no=5881&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-5-breakfast/viewer?title_no=5881&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-4-high-striker/viewer?title_no=5881&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-3-following-day/viewer?title_no=5881&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-2-text-her/viewer?title_no=5881&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/skylie/ep-1-summer-break/viewer?title_no=5881&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-6-knock-off/viewer?title_no=4603&episode_no=6': 'Action',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-5-when-a-martian-calls/viewer?title_no=4603&episode_no=5': 'Action',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-4-the-temple-of-fwoom/viewer?title_no=4603&episode_no=4': 'Action',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-3-the-lost-idol/viewer?title_no=4603&episode_no=3': 'Action',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-2-dead-before-proven-alive/viewer?title_no=4603&episode_no=2': 'Action',
#  'https://www.webtoons.com/en/action/red-hood-outlaws/ep-1-two-birds-one-clone/viewer?title_no=4603&episode_no=1': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-7-the-right-time/viewer?title_no=2575&episode_no=7': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-6-spirit-jinn/viewer?title_no=2575&episode_no=6': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-5-mineral-lizard/viewer?title_no=2575&episode_no=5': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-4-whats-a-goblins-favorite-type-of-fish/viewer?title_no=2575&episode_no=4': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-3-wanted/viewer?title_no=2575&episode_no=3': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-2-air-bullet/viewer?title_no=2575&episode_no=2': 'Action',
#  'https://www.webtoons.com/en/action/dungeons-and-artifacts/ep-1-memento-mortem/viewer?title_no=2575&episode_no=1': 'Action',
#  'https://www.webtoons.com/en/thriller/bastard/ep-10/viewer?title_no=485&episode_no=11': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-9/viewer?title_no=485&episode_no=10': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-8/viewer?title_no=485&episode_no=9': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-7/viewer?title_no=485&episode_no=8': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-6/viewer?title_no=485&episode_no=7': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-5/viewer?title_no=485&episode_no=6': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-4/viewer?title_no=485&episode_no=5': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-3/viewer?title_no=485&episode_no=4': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-2/viewer?title_no=485&episode_no=3': 'Thriller',
#  'https://www.webtoons.com/en/thriller/bastard/ep-1/viewer?title_no=485&episode_no=2': 'Thriller',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-13/viewer?title_no=4178&episode_no=13': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-12/viewer?title_no=4178&episode_no=12': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-11/viewer?title_no=4178&episode_no=11': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-10/viewer?title_no=4178&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-9/viewer?title_no=4178&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-8/viewer?title_no=4178&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-7/viewer?title_no=4178&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-6/viewer?title_no=4178&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-5/viewer?title_no=4178&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/our-secret-alliance/episode-4/viewer?title_no=4178&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-7/viewer?title_no=2010&episode_no=8': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-6/viewer?title_no=2010&episode_no=7': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-5/viewer?title_no=2010&episode_no=6': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-4/viewer?title_no=2010&episode_no=5': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-3/viewer?title_no=2010&episode_no=4': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-2/viewer?title_no=2010&episode_no=3': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-1/viewer?title_no=2010&episode_no=2': 'Thriller',
#  'https://www.webtoons.com/en/thriller/its-mine/episode-0-prologue/viewer?title_no=2010&episode_no=1': 'Thriller',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-7/viewer?title_no=5843&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-6/viewer?title_no=5843&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-5/viewer?title_no=5843&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-4/viewer?title_no=5843&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-3/viewer?title_no=5843&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-2/viewer?title_no=5843&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/my-office-rebound-marriage/episode-1-/viewer?title_no=5843&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/comedy/mage-and-demon-queen/episode-19/viewer?title_no=1438&episode_no=19': 'Comedy',
# ...
#  'https://www.webtoons.com/en/romance/luff/episode-9/viewer?title_no=1489&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-8/viewer?title_no=1489&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-7/viewer?title_no=1489&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-6/viewer?title_no=1489&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-5/viewer?title_no=1489&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-4/viewer?title_no=1489&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-3/viewer?title_no=1489&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-2/viewer?title_no=1489&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/luff/episode-1/viewer?title_no=1489&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-15-secret/viewer?title_no=99&episode_no=20': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-14-canine/viewer?title_no=99&episode_no=19': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-13-a-fly-3/viewer?title_no=99&episode_no=18': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-12-a-fly-2/viewer?title_no=99&episode_no=17': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-11-a-fly-1/viewer?title_no=99&episode_no=16': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-10-opening-act/viewer?title_no=99&episode_no=15': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-9-water-snake-3/viewer?title_no=99&episode_no=14': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-8-water-snake-2/viewer?title_no=99&episode_no=13': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-7-water-snake-1/viewer?title_no=99&episode_no=12': 'Drama',
#  'https://www.webtoons.com/en/drama/cheese-in-the-trap/ep-6-change/viewer?title_no=99&episode_no=11': 'Drama',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-10/viewer?title_no=3359&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-9/viewer?title_no=3359&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-8/viewer?title_no=3359&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-7/viewer?title_no=3359&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-6/viewer?title_no=3359&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-5/viewer?title_no=3359&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-4/viewer?title_no=3359&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-3/viewer?title_no=3359&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-2/viewer?title_no=3359&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/one-of-a-kind-romance/episode-1-/viewer?title_no=3359&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-12-aint-gonna-face-no-defeat/viewer?title_no=919&episode_no=14': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/interlude-2/viewer?title_no=919&episode_no=13': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-11-can-barely-stand-on-my-feet/viewer?title_no=919&episode_no=12': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-10-a-built-in-remedy/viewer?title_no=919&episode_no=11': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-9-recommended-at-the-price/viewer?title_no=919&episode_no=10': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-8-keep-losing-my-beat/viewer?title_no=919&episode_no=9': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-7-i-need-no-sympathy/viewer?title_no=919&episode_no=8': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/interlude-with-fanarts/viewer?title_no=919&episode_no=7': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-6-can-barely-stand-on-my-feet/viewer?title_no=919&episode_no=6': 'Comedy',
#  'https://www.webtoons.com/en/comedy/live-with-yourself/ep-5-cant-get-no-relief/viewer?title_no=919&episode_no=5': 'Comedy',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-14/viewer?title_no=1221&episode_no=14': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-13/viewer?title_no=1221&episode_no=13': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-12/viewer?title_no=1221&episode_no=12': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-11/viewer?title_no=1221&episode_no=11': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-10/viewer?title_no=1221&episode_no=10': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-9/viewer?title_no=1221&episode_no=9': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-8/viewer?title_no=1221&episode_no=8': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-7/viewer?title_no=1221&episode_no=7': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-6/viewer?title_no=1221&episode_no=6': 'Action',
#  'https://www.webtoons.com/en/action/hardcore-leveling-warrior/ep-5/viewer?title_no=1221&episode_no=5': 'Action',
#  'https://www.webtoons.com/en/action/a-useless-villain/episode-3/viewer?title_no=2969&episode_no=3': 'Action',
#  'https://www.webtoons.com/en/action/a-useless-villain/episode-2/viewer?title_no=2969&episode_no=2': 'Action',
#  'https://www.webtoons.com/en/action/a-useless-villain/episode-1/viewer?title_no=2969&episode_no=1': 'Action',
#  'https://www.webtoons.com/en/fantasy/patience-my-lady/episode-3/viewer?title_no=4151&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/patience-my-lady/episode-2/viewer?title_no=4151&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/patience-my-lady/episode-1/viewer?title_no=4151&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/romance/charming-you/episode-7/viewer?title_no=4156&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-6/viewer?title_no=4156&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-5/viewer?title_no=4156&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-4/viewer?title_no=4156&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-3/viewer?title_no=4156&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-2/viewer?title_no=4156&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/charming-you/episode-1/viewer?title_no=4156&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-6/viewer?title_no=3666&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-5/viewer?title_no=3666&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-4/viewer?title_no=3666&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-3/viewer?title_no=3666&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-2/viewer?title_no=3666&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/our-beloved-summer/episode-1/viewer?title_no=3666&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-7/viewer?title_no=4686&episode_no=7': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-6/viewer?title_no=4686&episode_no=6': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-5/viewer?title_no=4686&episode_no=5': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-4/viewer?title_no=4686&episode_no=4': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-3/viewer?title_no=4686&episode_no=3': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-2/viewer?title_no=4686&episode_no=2': 'Fantasy',
#  'https://www.webtoons.com/en/fantasy/saving-a-mercenary-unit-from-bankruptcy/episode-1/viewer?title_no=4686&episode_no=1': 'Fantasy',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-8/viewer?title_no=421&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-7/viewer?title_no=421&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-6/viewer?title_no=421&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-5/viewer?title_no=421&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-4-/viewer?title_no=421&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-3/viewer?title_no=421&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-2/viewer?title_no=421&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/where-tangents-meet/ep-1/viewer?title_no=421&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-7/viewer?title_no=1536&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-6/viewer?title_no=1536&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-5/viewer?title_no=1536&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-4/viewer?title_no=1536&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-3/viewer?title_no=1536&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-2/viewer?title_no=1536&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/edith/episode-1/viewer?title_no=1536&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-10/viewer?title_no=5435&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-9/viewer?title_no=5435&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-8/viewer?title_no=5435&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-7/viewer?title_no=5435&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-6/viewer?title_no=5435&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-5/viewer?title_no=5435&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-4/viewer?title_no=5435&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-3/viewer?title_no=5435&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-2/viewer?title_no=5435&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/the-guy-with-pretty-lips/episode-1/viewer?title_no=5435&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-7/viewer?title_no=3670&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-6/viewer?title_no=3670&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-5/viewer?title_no=3670&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-4/viewer?title_no=3670&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-3/viewer?title_no=3670&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-2/viewer?title_no=3670&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/cierra/episode-1/viewer?title_no=3670&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-14/viewer?title_no=1893&episode_no=14': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-13/viewer?title_no=1893&episode_no=13': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-12/viewer?title_no=1893&episode_no=12': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-11/viewer?title_no=1893&episode_no=11': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode10/viewer?title_no=1893&episode_no=10': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-9/viewer?title_no=1893&episode_no=9': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-8/viewer?title_no=1893&episode_no=8': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-7/viewer?title_no=1893&episode_no=7': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-6/viewer?title_no=1893&episode_no=6': 'Horror',
#  'https://www.webtoons.com/en/horror/gremoryland/episode-5/viewer?title_no=1893&episode_no=5': 'Horror',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-10/viewer?title_no=1471&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-9/viewer?title_no=1471&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-8/viewer?title_no=1471&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-7/viewer?title_no=1471&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-6/viewer?title_no=1471&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-5/viewer?title_no=1471&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-4/viewer?title_no=1471&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-3/viewer?title_no=1471&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-2/viewer?title_no=1471&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/ghost-wife/episode-1/viewer?title_no=1471&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-10/viewer?title_no=1390&episode_no=10': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-9/viewer?title_no=1390&episode_no=9': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-8/viewer?title_no=1390&episode_no=8': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-7/viewer?title_no=1390&episode_no=7': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-6/viewer?title_no=1390&episode_no=6': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-5/viewer?title_no=1390&episode_no=5': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-4-/viewer?title_no=1390&episode_no=4': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-3/viewer?title_no=1390&episode_no=3': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-2/viewer?title_no=1390&episode_no=2': 'Romance',
#  'https://www.webtoons.com/en/romance/a-good-day-tobe-a-dog/ep-1/viewer?title_no=1390&episode_no=1': 'Romance',
#  'https://www.webtoons.com/en/horror/tales-of-the-unusual/ep-18-to-kill-a-magician-part-2/viewer?title_no=68&episode_no=19': 'Horror',
#  'https://www.webtoons.com/en/horror/tales-of-the-unusual/ep-17-to-kill-a-magician-part-1/viewer?title_no=68&episode_no=18': 'Horror',
#  'https://www.webtoons.com/en/horror/tales-of-the-unusual/ep-16-an-african-incident-part-6/viewer?title_no=68&episode_no=17': 'Horror',
#  'https://www.webtoons.com/en/horror/tales-of-the-unusual/ep-15-an-african-incident-part-5/viewer?title_no=68&episode_no=16': 'Horror',
#  ...}

# %%
import matplotlib.pyplot as plt
r = requests.get("https://www.webtoons.com/en/action/viral-hit/ep-9-i-want-to-rip-myself-to-shreds/viewer?title_no=2268&episode_no=9")
soup = BeautifulSoup(r.text, 'html.parser') # Use BeautifulSoup on response

a = soup.find('div', class_=re.compile('^viewer_img _img_viewer_area.*'), id="_imageList").find_all('img', class_='_images')[0]['data-url']

requests.get(a, headers = {"referer": "https://www.webtoons.com/"}).content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc2\x00\x11\x08\x03\xe8\x02\xb2\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x01\x00\x01\x05\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x07\x01\x03\x04\x05\x06\x08\x02\t\xff\xc4\x00\x19\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\xff\xda\x00\x0c\x03\x01\x00\x02\x10\x03\x10\x00\x00\x01\xf5H\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x048Lo/\xf4d\xfa\xb3\x16\x12\xca\x1d\xd5\x93\xb2\x1a\x99C\xcf\x1d!1\xa0L\x82s@{\xa2bB2\x11\xd6<\xf1C\xd1\x08\x9fRM\xc82\xe97!\xc9\x14\xdf#~\\\x9c\x11\x97\nz\x1d\xe7\x9e\xd0\x94\x90~\xd4\x96\xd1ljzq\xc4\xc5g\xa2\x9ah\xd8\x98\x9eJ\xf5\x01\xb5B\xba\xa2\x7fq;#\xa4y\xff\x00\xb1$\xf7\x9e\xf2I\xed\xe7\xfb\xa4\xf6\x8d\xb8c\xd0O=\xef\x89\x99\x17\xda%TG\x80Mh\xff\x00\xe4\x90\x9c\xf7B\x1ej\xf49\x9c\xf2\xbf\xa7\x8c\xa4W\xc8\x1e\x83B\x1fd\xd8D\x84\xb6\xe2x\x82ms\x911>!\x9di<!\xc9<\xda\x00\x00\x00\x806:\xed\x89k\x8c\xf4\xfc$be\xe2Ig\x1b3y\x87\xd3G\x97\xa4\x1ejp \xee\xa3\x95\x9e\xcf-K5\xdb\x11\xe6\xd7\xb8\x85\x8fD\xe2G\xb6\x08\xc3\xd6\x1e{\x98\xc8\xd7Mg|m\xe5\x0b[\x12\x08\x9f\xfc\xfb.\x1c\x97A\xcci\t\x87\xc9\xf3\x1f\x1c6\x12\xd7\x90\x8fr\xc13\xb4\x12NPn\xfbD\\\xc1\xd3nM\x07P\xe7\x0e\x9f\x9a\xe8%\x12\x99\x90\\\xde@\xf3u\xc8H\x93\xf6Z\xdd\x91\x13l\xbe\xaaG>\xba\x83\xfa\x92\xc4S\xbc\xb8^\xd9w^y;YF#\x9d\x8d/=\xc9\xf5\x87W\xbe\xe2\xb8\xe3\x1fgg\x9c36W\xf4\x87\x1b\xe8\xb8\x7fnn\xb9\x9d\xcf\x1czj\t\x92bSg\xf3\xc9m\xcc\xa9\xcb\xcf2\xa9\xa6\xe1s2\xcd\xcc\xaf\x87\xb4.\x80\x01`\xbe\xc0\x18\x976\x17\x8f\x9dN\xc8j\xf4\x9d\x9e\x19\xcd\xf6X\x19\x07\'\xae\xef/\x9c\xe7I\xf1\xf2`\xe2\xed\xee\x91\x9c\x95\xf1x\xe3~\xfa\x9f\x83\x13\x92\xed\xb2\x0b\x1aM\xb5\xd3\x85\xec65>cy\x1b\xe4\xc1\xd4t\xb9\x07\x15\xd2|\xecO\x8ewqS;O\x9217X\x03\x16\x99\xff\x00f\xbf\xefaCW\xc5I\xfa\xe3\xea\xfd\xcf\xb22\xef\xabp\xf8\xb9r\xc1\x89\xb0\xbd\x84cs]\xe5Nk7+$\xbb\xcdtx\x05\xf8\xeeN\xc61~\xb68\xc7\t\x95\xd8\xd93\xf4\x9b{F\x15\xdb\xf7\x8d~\xb3qt\xe1\xa4\x0f\x9f\xa27\xee2\x86\x16\xd6\xb8f\x17=\xd5\xdd9{\xdd\x16Q\x1d\xf6\xd6\xb6E@\x03\x98\xe9\xc7\x93\xe5\x8d\x1c\xe8@3\xf7\x94\xbb\xf3\\\xf9\xe7\x89"\xec\x7f\xe9S\xc9\xbe\x88\x8c\xe7c\xcc\x92g\x1f|\xb9{_\x96i\xbb\xd8\xaffe\xf5\x9d\x9c&M\x90\xe7\xa2|\xe0m\xb0>jd\xc8\x91\xd4\x9ak\xf6Z\xdd\x91\x19\xd9\xc8\xc46\\\x17q\xdd\x1c\xe7K\x17\xf7\x04m%F\x93\t\xc1\xe8\'\x0eP\xb1\x14\xfa\xca\t3\xf8i\xba\x116y\xd9\x1c\xd1\xd7\xec9\xc9l\xe6{(\xceL<\xf3,C=\x99\xcf\xf4=\\\x9cAZ\xaec<\xdaN\xb1\x0c\xecy\xa6Z\xe0\xb6\x87%\xd6\xe8\xfd\x04CP\x0c\xbd\xc2\x9e\xbe\xf0\xc4\xe1\xc5\x9d\x0f_\xc8u\xc4\x89\t\xce\xb0!\xbd\xe16[\x82\xe4\x83\x1e\xc9d{\x97\xc4\xdc6\xbd\x16\xbat \x1e\x7fu\xa5$.K\xb2\xe3\x8d\xb7#zd8Y\x12!\x90\x89 \x00\x01\x08\xcd\xc1\x03\xcf\x01\xe4\x19\xeeC\x104\xe3\x90 \xf9\xc0 l\xc9\xb4E\xd0\x9f\xafG\x13\x1c\xcf\x83\xe2\x12\x9c\x03\xce\xde\x89\x10^\x83\xd2c\xceR4\x8e4\xb0\'\xa5G\x9b\xba\x19\xc08^\xe8Av\xe7\x81\xe5yNU\x1c\xbf-(\x84\x1f8\x0eB\x16\xf4\xc0\xd6\xf8\xe3\xdb"\x1b\xc6\x9bG\x9d\xe6\xfd\xc8\x89\xe5+\xc3\xcd[\x0fB\x88k\xa2\x90\xc7\x9dg=\xb8\x82\xb0\xfd\x02<\xef\xb0\x9e\x04O\xa6\x9cG\x92;\xe9\xe4y\xdbw7\r\x0cK<\x08\xd68\xf4\x88\xf3\xb6\xdas\x11>\xa2o\x1eg\xea\xe6\xd1\x0fp\x1e\xa0\x10\x8d\x99\xd0F\x1c\xec\xe2 \xcf\x89\xd8G\xf2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ ...

# %%
async def fetch_page_url_genre_dict(session, comic_episode_url, genre):
    """
    Helper function for create_page_url_with_genres_dict. 
    Fetches the page_url_genre_dict for a given episode

    Args:
        session (aiohttp.client.ClientSession()): Allows asynchronous processing of requests
        comic_episode_url (string): WebToon original comic episode URL 
        genre (string): Genre associated with the comic
    Returns:
        page_url_genre_dict(Dict(string,string)): A Dictionary mapping comic page URLs from one episode to their associated genre
    """
    async with session.get(comic_episode_url, headers={"referer": "https://www.webtoons.com/"}) as response: # Request response
        page_url_genre_dict = {}
        
        r = await response.text() # Await a response
        soup = BeautifulSoup(r, 'html.parser') # Use BeautifulSoup on response
        
        pages = soup.find('div', class_=re.compile('^viewer_img _img_viewer_area')).find_all('img', class_='_images')
        
        for page in pages:
            page_url = re.sub("\?type=\w*", "", page['data-url']) # Get url for a comic page and remove its image type
            page_url_genre_dict[page_url] = genre
        
        return page_url_genre_dict
        
async def create_page_url_with_genres_dict(episode_url_genre_dict): # Scrape episode URLs for each comic series URL
    """
    Creates a dictionary associating WebToons original comic page URLs to their associated genre

    Args:
        episode_url_genre_dict (Dict(string,string)): A Dictionary mapping comic episode URLs to their associated genres
    Returns:
        page_url_genre_dict (Dict(string,string)): A Dictionary mapping comic page URLs to their associated genres
    """
    tasks = []
    start = time.time()
    async with aiohttp.ClientSession() as session: # Allows asynchronous processing of requests
        async with asyncio.TaskGroup() as tg: # Gathers all tasks (if any error, the whole thing errors)
            for comic_episode_url, genre in episode_url_genre_dict.items():
                task = tg.create_task(fetch_page_url_genre_dict(session, comic_episode_url, genre)) # Create task for fetching 
                tasks.append(task)
    print(f"Finished asyncio page url dict in {time.time()- start}s")
    page_url_genre_dict = {comic_page_url: genre for task in tasks for comic_page_url, genre in task.result().items()} # Extract and concatenate dictionaries inside finished tasks
    return episode_url_genre_dict

# %%
# NEW
async def download_image_2(url, directory, filename, semaphore):
    headers = {"referer": "https://www.webtoons.com/"}

    async with aiohttp.ClientSession() as session:
        async with semaphore:
            response = await client.get(url, headers=headers)
            assert response.status_code == 200
            async with aiofiles.open(os.path.join(directory, filename), "wb") as f:
                await f.write(response.content)
# OLD
async def download_image(url, directory, filename, semaphore):
    headers = {"referer": "https://www.webtoons.com/"}

    async with httpx.AsyncClient() as client:
        async with semaphore:
            response = await client.get(url, headers=headers)
            if response.status_code == 200:
                async with aiofiles.open(os.path.join(directory, filename), "wb") as f:
                    await f.write(response.content)

async def main():
    image_directory = 'comic_pages'
    os.makedirs(image_directory, exist_ok=True)
    for episode_url, genre in list(episode_url_genre_dict.items())[:2]:
        genre_directory = f"{image_directory}/{genre}"
        os.makedirs(genre_directory, exist_ok=True)
        async with httpx.AsyncClient() as client:
            r = await client.get(episode_url)
        soup = BeautifulSoup(r.content, 'html.parser')
        for img in list(soup.find_all('img', class_='_images'))[0:100:8]:
            img_url = re.sub("\?type=\w*", "", img['data-url'])
            filename = img_url.split('/')[-1]
            tasks.append(download_image(img_url, genre_directory, filename, semaphore))  # Pass semaphore here

# %%
# Downloading JPG files of comic page images to disk sorted into directories based on genre

import random
async def download_image(url, directory, filename, semaphore):
    headers = {"referer": "https://www.webtoons.com/"}

    async with httpx.AsyncClient() as client:
        async with semaphore:
            response = await client.get(url, headers=headers)
            if response.status_code == 200:
                async with aiofiles.open(os.path.join(directory, filename), "wb") as f:
                    await f.write(response.content)

async def main():
    start_time = time.time()
    image_directory = 'images'
    if not os.path.exists(image_directory):
        os.makedirs(image_directory)
    # Download images for each episode URL asynchronously
    tasks = []
    counter = 0
    for episode_url, genre in list(episode_url_genre_dict.items())[0:len(episode_url_genre_dict):2]:
        genre_directory = f"{image_directory}/{genre}"
        if not os.path.exists(genre_directory):
            os.makedirs(genre_directory)
        async with httpx.AsyncClient() as client:
            r = await client.get(episode_url)
        soup = BeautifulSoup(r.content, 'html.parser')
        for img in list(soup.find_all('img', class_='_images'))[0:100:8]:
            img_url = re.sub("\?type=\w*", "", img['data-url'])
            filename = img_url.split('/')[-1]
            tasks.append(download_image(img_url, genre_directory, filename, semaphore))  # Pass semaphore here
        counter += 1
        print(f"finished {episode_url} {counter} {time.time() - start_time}")
    print(time.time() - start_time)
    await asyncio.gather(*tasks)

if __name__ == "__main__":
    asyncio.run(main())

# %% [markdown]
# ## Loading Images From the Images Directory For OCR & Writing Features and Labels to Disk After Formatting

# %%
import os
from PIL import Image
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
import time

pytesseract.pytesseract.tesseract_cmd = r'/opt/local/bin/tesseract'

img_data = []
text_data = []
genre_data = []

start_time = time.time()

Path = 'images'
for genre in os.listdir(Path):
    genre_start_time = time.time()
    if genre == '.DS_Store':
        continue
    path = os.path.join(Path, genre)
    for images in os.listdir(path):
        if images == '.DS_Store':
            continue
        path1 = os.path.join(path,images)
        image = Image.open(path1)
        text = pytesseract.image_to_string(image).strip()
        if text:
            text_data.append(text)
            genre_data.append(genre)
            image = image.resize((100,125))
            image = image.convert('RGB')
            img_data.append(np.array(image))
    print(f"finished {genre} in {time.time()-genre_start_time}")

import pickle

# write list to binary file
def write_list(filename, input_list):
    # store list in binary file so 'wb' mode
    with open(filename, 'wb') as fp:
        pickle.dump(input_list, fp)

np.save('img_data_new', np.array(img_data).astype('int8'))
write_list('text_data_new.bin', text_data)
write_list('genre_data_new.bin', genre_data)

print(f"finished everything in {time.time()-start_time}")

# %% [markdown]
# ### Note: Uploaded files written to disk above into Google Drive so that we could work with them on Google Colab

# %% [markdown]
# ## Preprocessing & Training Neural Network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from transformers import DistilBertModel, DistilBertTokenizer
import numpy as np
import time
import os
import pickle
from PIL import Image
import torchvision.transforms as transforms
import torchvision.models as models
from sklearn.preprocessing import LabelEncoder
from google.colab import drive
from google.colab import userdata
userdata.get('HuggingFace')

def create_data_folder(user): # Different path to folder depending on user
    if user.lower() == 'brooke':
        return '/content/drive/MyDrive/Final Project'
    if user.lower() == 'zach':
        return '/content/drive/MyDrive/Year 2/Spring 2024/DS340/FinalProject'
    return '/content/drive/MyDrive/Final Project'

# Define the path to the folder containing the data
drive.mount('/content/drive')
data_folder = create_data_folder('zach') #change to 'brooke' when you use it

# neural network classifier
class GenreClassifier(nn.Module):
    def __init__(self, text_input_size, image_input_size, hidden_size, num_classes):
        super(GenreClassifier, self).__init__()
        self.text_fc1 = nn.Linear(text_input_size, hidden_size)
        self.image_fc1 = nn.Linear(image_input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, text_x, image_x):
        text_out = self.relu(self.text_fc1(text_x))
        image_out = self.relu(self.image_fc1(image_x))
        combined = torch.cat((text_out, image_out), dim=1)
        out = self.fc2(combined)
        return out

# DistilBERT model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertModel.from_pretrained('distilbert-base-uncased')

# NN layer that does nothing (used to replace output layer of ResNet50)
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()

    def forward(self, x):
        return x

# Load ResNet50 model
resnet = models.resnet50(pretrained=True)
resnet.eval()
for param in resnet.parameters():
    param.requires_grad = False
resnet.fc = Identity()

# preprocessing for text
def get_tokens(text):
    return tokenizer(text, return_tensors="pt", padding=True, truncation=True)

# preprocessing for images
preprocess_image = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# extract image features using ResNet50
def extract_image_features_resnet(img_arr):
    image = Image.fromarray(np.uint8(img_arr))
    image = preprocess_image(image).unsqueeze(0) #shape(1,3,224,224)
    with torch.no_grad():
        features = resnet(image) # shape (1,2048)
    features = torch.nn.functional.relu(features)  # ReLU activation ; shape (1,2048)
    #features = torch.nn.functional.adaptive_avg_pool2d(features, (1, 1))  # Global average pooling
    features = features.squeeze() # shape (2048)
    return features

# helper function for load_data() for reading binary files
def read_bin(filename):
    with open(filename, 'rb') as fp:
        n_list = pickle.load(fp)
        return n_list

# load data
def load_data():
    img_data = np.load('/content/drive/MyDrive/Year 2/Spring 2024/DS340/FinalProject/img_data2.npy', allow_pickle=True)
    text_data = read_bin('/content/drive/MyDrive/Year 2/Spring 2024/DS340/FinalProject/text_data.bin')
    genre_data = read_bin('/content/drive/MyDrive/Year 2/Spring 2024/DS340/FinalProject/genre_data.bin')
    return img_data, text_data, genre_data

# combine features and labels
# def combine_features_and_labels(img_data, text_data):
#     since = time.time()
#     text_features_list = []
#     image_features_list = []
#     counter = 0
#     for img in img_data:
#         image_features = extract_image_features_resnet(img).detach().numpy()
#         image_features_list.append(image_features)
#         if counter%100 == 0:
#             print(f"{counter/len(img_data)*100}% done with images")
#         counter += 1
#     print(f"images finished: {time.time()-since}")
#     since = time.time()
#     counter = 0
#     for text in text_data:
#         tokens = get_tokens(text)
#         outputs = model(**tokens)
#         text_features = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
#         text_features_list.append(text_features)
#         if counter%100 == 0:
#             print(f"{counter/len(text_data)*100}% done with text")
#         counter += 1
#     print(f"text finished: {time.time()-since}")

#     text_features_array = np.array(text_features_list)
#     image_features_array = np.array(image_features_list)

#     print(f"{text_features_array.nbytes} bytes in text_array")
#     print(f"{image_features_array.nbytes} bytes in image_array")

#     # flatten
#     text_features_flat = text_features_array.reshape(-1)
#     image_features_flat = image_features_array.reshape(-1)

#     # concatenate
#     combined_features = np.concatenate((text_features_flat, image_features_flat), axis=0)

#     return combined_features

def combine_features_and_labels(img_data, text_data, batch_size):
    since = time.time()
    combined_features_list = []
    for i in range(0, len(img_data), batch_size):
        img_batch = img_data[i:i+batch_size]
        text_batch = text_data[i:i+batch_size]

        image_features_batch = []
        text_features_batch = []
        for img in img_batch:
            image_features = extract_image_features_resnet(img).detach().numpy()
            image_features_batch.append(image_features)

        for text in text_batch:
            tokens = get_tokens(text)
            outputs = model(**tokens)
            text_features = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
            text_features_batch.append(text_features)

        mean_image_features = np.mean(image_features_batch, axis=0)
        mean_text_features = np.mean(text_features_batch, axis=0)

        combined_features = np.concatenate((mean_text_features, mean_image_features))
        combined_features_list.append(combined_features)

        print(f"{i / len(img_data) * 100}% done with images and text")

    combined_features_array = np.array(combined_features_list)

    print(f"{combined_features_array.nbytes} bytes in combined features array")

    return combined_features_array

# Load and combine data
batch_size = 4
img_data, text_data, genre_data = load_data()
img_data = img_data
text_data = text_data
labels = genre_data[::batch_size]
label_encodings = dict(zip(np.unique(labels), np.arange(len(np.unique(labels)))))
labels = [*map(label_encodings.get, labels)]
features = combine_features_and_labels(img_data, text_data, batch_size)

# Split data into train/test sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

print(X_train)
print(X_train.shape)
print(y_train)

# Convert data to tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# params
input_size_text = X_train.shape[1] // 2  # Assuming text and image features have the same size
input_size_image = X_train.shape[1] // 2
hidden_size = 128
num_classes = len(np.unique(labels))
num_epochs = 10
batch_size = 64
learning_rate = 0.001
train_dataset = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
classifier = GenreClassifier(input_size_text, input_size_image, hidden_size, num_classes)

# loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(classifier.parameters(), lr=learning_rate)

# training
start_time = time.time()
for epoch in range(num_epochs):
    total_loss = 0
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        text_inputs = inputs[:, :input_size_text]  # Extract text features
        image_inputs = inputs[:, input_size_text:]  # Extract image features
        outputs = classifier(text_inputs, image_inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss/len(train_loader):.4f}")

print(f"Training finished in {time.time() - start_time} seconds.")

# evaluation
# evaluation
with torch.no_grad():
    outputs = classifier(X_test_tensor[:, :input_size_text], X_test_tensor[:, input_size_text:])
    _, predicted = torch.max(outputs, 1)
    test_accuracy = (predicted == y_test_tensor).sum().item() / len(y_test_tensor)
    print(f"Test Accuracy: {test_accuracy:.4f}")
